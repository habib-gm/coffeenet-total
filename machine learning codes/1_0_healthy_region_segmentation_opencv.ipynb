# %% [markdown]
# ## Segmentation of healthy leaf and leaf area calculation

# %%
import os
import glob
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
""" Dataset path"""
leaf_data_path = "/Users/aic/Downloads/kebna_january_data_1" #"../Data/leaf"
os.path.exists(leaf_data_path)
# Out:
# True

# %%
images = glob.glob(leaf_data_path+"/*.jpg")
images
# Out:
# ['/Users/aic/Downloads/kebna_january_data_1/114127.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/7_103957.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113847.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114319.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/115007.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105228.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111315.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113502.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104730.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105604.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114047.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111856.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114913.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112351.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111102.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104057.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120730.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124218.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110817.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110142.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112033.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120526.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124026.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123749.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123946.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113111.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/12253.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112233.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104109.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105217.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112019.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112031.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114440.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104647.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123213.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121410.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124226.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105405.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111302.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112623.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120652.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/12333.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123824.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113059.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123830.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114904.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105809.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104530.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110545.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104256.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111129.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112346.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105612.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110948.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112811.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114535.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/103707.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110828.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112742.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110627.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105202.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120531.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110425.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114135.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112222.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124009.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120509.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110151.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110838.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121415.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112154.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110233.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113048.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113706.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123809.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111110.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114732.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114054.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104910.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123411.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121212.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104904.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114518.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113511.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/103716.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104737.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112141.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/115000.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104657.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113840.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111925.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/7_104024.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114652.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113129.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_104440.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104319.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111933.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124036.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105239.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114452.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110634.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113301.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121402.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113513.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/103927.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123836.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110219.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104244.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112340.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121205.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105402.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114241.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124209.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_104119.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_104131.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105947.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/98.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104456.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114645.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123943.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111000.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112509.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112521.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123930.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121114.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105920.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113830.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110108.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112051.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121316.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121302.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/103835.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/103821.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111404.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112643.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120632.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110518.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114018.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113005.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112455.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111148.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105854.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124124.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113944.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111834.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114031.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121908.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105458.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114227.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112118.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114347.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120948.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114409.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124045.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114838.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111954.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121129.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_114152.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113600.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110447.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104354.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110335.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112244.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113416.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111215.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110645.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105300.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110057.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112126.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104036.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110533.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105658.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121922.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113953.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114740.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121248.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110724.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105329.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114218.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113359.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110136.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105249.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111943.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120546.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121102.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104427.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104433.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105711.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105932.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114340.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104153.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104621.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124240.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114552.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114220.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_114545.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113229.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114208.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110913.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104543.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110244.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104219.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123658.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112446.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114037.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112320.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121932.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120621.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112903.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104813.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112718.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111205.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110655.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104634.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121107.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/23957.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104344.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123923.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114625.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110327.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111005.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/122424.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113821.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114828.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/122430.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112732.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113202.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104554.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123841.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124108.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124134.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111825.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114752.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111158.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121925.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110905.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105307.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112653.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124256.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105515.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112041.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114801.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113613.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114632.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110459.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123905.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_112517.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113811.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114818.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111237.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120954.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112058.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112716.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110854.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112919.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113554.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112104.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121243.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120607.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111141.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114011.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121914.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123656.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114945.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123858.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113743.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124312.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_080711_945.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111418.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121322.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113353.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114428.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113637.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123938.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111750.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114416.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121308.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120638.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104229.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104201.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_125233.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111802.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105650.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113218.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104758.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121335.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104604.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110117.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105526.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104406.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113630.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111741.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123718.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113803.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111225.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123240.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110715.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105318.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114201.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112843.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110259.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113750.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123645.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_112316.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114002.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112301.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112856.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120600.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104749.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124248.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113341.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113619.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_112510.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_114607.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110312.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111018.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_105734.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/122411.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/7_103938.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105938.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112707.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113425.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/13243.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_104006.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/103742.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111346.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124302.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120616.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_112328.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113021.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111811.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124114.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121050.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123849.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110930.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110924.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124317.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111353.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104825.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/103810.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123732.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105911.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113154.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111031.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105722.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113140.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104414.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114613.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110348.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105751.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111042.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121156.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121142.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124006.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113325.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123225.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104842.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_103848.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120738.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/103730.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114502.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120658.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112832.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121220.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/103903.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_112428.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105625.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105817.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104506.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/10507.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121235.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114259.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113318.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113442.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123740.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104328.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112548.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113656.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123742.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111914.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120934.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110613.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121343.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121357.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110029.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112602.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104921.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111121.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123637.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111849.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114702.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112415.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123810.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/103915.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110941.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104707.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104049.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114528.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111336.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110809.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112005.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112011.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114306.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/103652.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105551.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123757.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114845.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113119.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110438.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114114.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111050.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/23914.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105958.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110602.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112954.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110010.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112613.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105421.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111326.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104930.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114712.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_112412.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113727.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105151.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124148.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123633.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105636.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105434.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105352.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110039.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113524.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114511.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113450.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114459.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/120501.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/24922.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110417.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/1.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124017.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111906.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114856.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121147.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/_104139.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113334.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/103641.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/124201.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123234.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104714.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113532.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105344.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114249.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123817.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113730.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114937.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114923.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/123802.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/113719.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114704.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110204.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121230.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/121422.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/104852.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/111244.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/114328.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/105543.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/112215.jpg',
#  '/Users/aic/Downloads/kebna_january_data_1/110402.jpg']

# %% [markdown]
# 1. Using Image processing only technique

# %%
class SegmentLeaf:
    def __init__(self):
        pass

    def __call__(self,image):
        mask = self.remove_background(image)
        contour,area = self.find_contour(mask)
        return mask,contour,area

    def remove_background(self,image):
        # Gaussia blur
        blured = cv2.GaussianBlur(image,(1,1),0)
        # Convert RGB image to HSV
        leaf_hsv = cv2.cvtColor(blured,cv2.COLOR_BGR2HSV)
        # Get mask from the S and V channels
        SV_channel = leaf_hsv.copy()
        # Set the H channel to zero
        SV_channel[...,0] = np.zeros((leaf_hsv.shape[0],leaf_hsv.shape[1]))
        # get binary mask
        mask = cv2.inRange(SV_channel,(0,0,80),(0,50,255))
        # Invert mask, White areas represent green components and black the background
        mask = cv2.bitwise_not(mask)
        return mask

    def find_contour(self,mask):
        # find all contours on the maks
        contours, heirarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        # filter the largest contour
        largest_contour = max(contours,key=cv2.contourArea)
        #print(largest_contour)
        # get area of the largest contour
        contour_area = cv2.contourArea(largest_contour)
        return largest_contour,contour_area

# %% [markdown]
# 2. Using Unet

# %%
import sys
import torch

sys.path.append(os.path.abspath(".."))
from elunet.elunet import ELUnet

device = torch.device("cpu")
print(f"torch version : {torch.__version__}")
# Out:
# torch version : 1.12.1

# %%
elunet = ELUnet(3,1,16)
healthy_checkpoint = torch.load("../elunet_checkpoint/elunet_healthy_leaf_2023-03-05.pth",map_location=device)
symptom_checkpoint = torch.load("../elunet_checkpoint/elunet_symptom_leaf_2023-03-05.pth",map_location=device)

# %%
import torchvision.transforms as transforms
transform = transforms.Compose([transforms.ToTensor(),transforms.Resize((256,256))])

# %% [markdown]
# #### Segment sample image

# %%
with torch.no_grad():
    elunet.eval()
    # read image
    image = cv2.imread(random.choice(images))
    image = cv2.resize(image,(256,256))
    # bgr to rgb
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    tensor_image = transform(image)

    # Init leaf segment
    segment = SegmentLeaf()
    mask,contour,area = segment(image)
    # Overlay image and mask
    segmented_leaf = cv2.bitwise_and(image,image,mask=mask)
    cv2.drawContours(image, contour, -1, (255,0,255), 3)

    # Using Unet

    tensor_image = tensor_image.unsqueeze(0).to(device)


    unet_mask = elunet(tensor_image)
    unet_mask = unet_mask[0].permute(1,2,0).detach().numpy()

    plt.figure(figsize=(10,5))
    plt.subplot(1,3,1)
    plt.title(f"Area in pixels:{area:,}")
    plt.imshow(image)

    plt.subplot(1,3,2)
    plt.imshow(mask,cmap="gray")
    plt.title(f"Healthy area:{np.sum(mask):,}")

    infected_pixels = np.sum(unet_mask[...,0])
    healthy_pixels = np.sum(unet_mask[...,1])

    print(infected_pixels)
    print(healthy_pixels)

    severity = infected_pixels / healthy_pixels

    plt.subplot(1,3,3)
    plt.imshow(unet_mask,cmap="gray")
    plt.title(f"Severity: {severity * 100:3f}%")

    plt.show()

# %% [markdown]
# ## Quantize and export Unet model

# %%
dummy_input = torch.randn(1,3,256,256)

# %% [markdown]
# ** Quantize healthy leaf segmentation model **

# %%
elunet.load_state_dict(symptom_checkpoint)
# Out:
# <All keys matched successfully>

# %%
unet_torchscript = torch.jit.trace(elunet, dummy_input)

# %%
#Then optimize the TorchScript formatted model for mobile and save it:
from torch.utils.mobile_optimizer import optimize_for_mobile
torchscript_unet_optimized = optimize_for_mobile(unet_torchscript)
torch.jit.save(torchscript_unet_optimized, "symptom_unet_quantized.pt")
